# %% [markdown]
# # Data Cleaning Notebook
# In this notebook, we clean and prepare the U.S. e-commerce dataset for analysis.

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv('../data/us_ecommerce_sales.csv')
df.head()
